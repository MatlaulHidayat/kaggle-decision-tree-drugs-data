# %% [markdown]
# <a href="https://colab.research.google.com/github/MatlaulHidayat/kaggle-decision-tree-drugs-data/blob/main/Tugas2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
df = pd.read_csv('car_purchasing.csv', encoding='ISO-8859-1')
df.head()
# Out:
#      customer name                                    customer e-mail  \
# 0    Martina Avila  cubilia.Curae.Phasellus@quisaccumsanconvallis.edu
# 1    Harlan Barnes                                eu.dolor@diam.co.uk
# 2  Naomi Rodriquez  vulputate.mauris.sagittis@ametconsectetueradip...
# 3  Jade Cunningham                            malesuada@dignissim.com
# 4     Cedric Leach     felis.ullamcorper.viverra@egetmollislectus.net
#
#         country  gender        age  annual Salary  credit card debt  \
# 0      Bulgaria       0  41.851720    62812.09301      11609.380910
# 1        Belize       0  40.870623    66646.89292       9572.957136
# 2       Algeria       1  43.152897    53798.55112      11160.355060
# 3  Cook Islands       1  58.271369    79370.03798      14426.164850
# 4        Brazil       1  57.313749    59729.15130       5358.712177
#
#      net worth  car purchase amount
# 0  238961.2505          35321.45877
# 1  530973.9078          45115.52566
# 2  638467.1773          42925.70921
# 3  548599.0524          67422.36313
# 4  560304.0671          55915.46248

# %%
df.drop(columns=['customer name', 'customer e-mail', 'country', 'gender'], inplace=True)
df.head()
# Out:
#          age  annual Salary  credit card debt    net worth  \
# 0  41.851720    62812.09301      11609.380910  238961.2505
# 1  40.870623    66646.89292       9572.957136  530973.9078
# 2  43.152897    53798.55112      11160.355060  638467.1773
# 3  58.271369    79370.03798      14426.164850  548599.0524
# 4  57.313749    59729.15130       5358.712177  560304.0671
#
#    car purchase amount
# 0          35321.45877
# 1          45115.52566
# 2          42925.70921
# 3          67422.36313
# 4          55915.46248

# %%
df.info()
df.isna().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 5 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   age                  500 non-null    float64
#  1   annual Salary        500 non-null    float64
#  2   credit card debt     500 non-null    float64
#  3   net worth            500 non-null    float64
#  4   car purchase amount  500 non-null    float64
# dtypes: float64(5)
# memory usage: 19.7 KB
# age                    0
# annual Salary          0
# credit card debt       0
# net worth              0
# car purchase amount    0
# dtype: int64

# %%
plt.scatter(df['annual Salary'] , df['credit card debt'])
plt.xlabel('annual Salary')
plt.ylabel('credit card debt')
plt.title('the corr between credit card debt and annual Salary')
# Out:
# Text(0.5, 1.0, 'the corr between credit card debt and annual Salary')

# %%
sns.pairplot(df)

# %%
X = df.iloc[:, :-1]
y = df.iloc[:, -1]
scale = MinMaxScaler()
X = scale.fit_transform(X)
y = scale.fit_transform(y.values.reshape(-1, 1))
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.2)
#Trying linear regression
lreg = LinearRegression()
lreg.fit(X_train, y_train)
print('Train score', lreg.score(X_train, y_train))
print('Test score', lreg.score(X_test, y_test))
# Out:
# Train score 0.9999999812227418
# Test score 0.9999999809931507

# %%
y_pred = lreg.predict(X_test)
ann = Sequential([Dense(32, activation="relu"),
                 Dense(1, activation='linear')])

ann.compile(optimizer='adam',
            loss='mean_squared_error',
            metrics=['mean_absolute_error'])


history = ann.fit(X_train, y_train, epochs=50, validation_split=0.2)
# Out:
# Epoch 1/50
# 10/10 [==============================] - 1s 27ms/step - loss: 0.4870 - mean_absolute_error: 0.6696 - val_loss: 0.4087 - val_mean_absolute_error: 0.6135
# Epoch 2/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.3393 - mean_absolute_error: 0.5528 - val_loss: 0.2746 - val_mean_absolute_error: 0.4963
# Epoch 3/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2211 - mean_absolute_error: 0.4370 - val_loss: 0.1689 - val_mean_absolute_error: 0.3800
# Epoch 4/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1277 - mean_absolute_error: 0.3224 - val_loss: 0.0898 - val_mean_absolute_error: 0.2653
# Epoch 5/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0641 - mean_absolute_error: 0.2153 - val_loss: 0.0380 - val_mean_absolute_error: 0.1646
# Epoch 6/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0265 - mean_absolute_error: 0.1304 - val_loss: 0.0159 - val_mean_absolute_error: 0.1049
# Epoch 7/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0160 - mean_absolute_error: 0.1009 - val_loss: 0.0127 - val_mean_absolute_error: 0.0874
# Epoch 8/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0151 - mean_absolute_error: 0.0976 - val_loss: 0.0128 - val_mean_absolute_error: 0.0869
# Epoch 9/50
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0145 - mean_absolute_error: 0.0956 - val_loss: 0.0120 - val_mean_absolute_error: 0.0855
# Epoch 10/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0136 - mean_absolute_error: 0.0926 - val_loss: 0.0117 - val_mean_absolute_error: 0.0861
# Epoch 11/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0131 - mean_absolute_error: 0.0904 - val_loss: 0.0115 - val_mean_absolute_error: 0.0857
# Epoch 12/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0127 - mean_absolute_error: 0.0891 - val_loss: 0.0112 - val_mean_absolute_error: 0.0844
# Epoch 13/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0123 - mean_absolute_error: 0.0876 - val_loss: 0.0109 - val_mean_absolute_error: 0.0834
# Epoch 14/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0119 - mean_absolute_error: 0.0862 - val_loss: 0.0107 - val_mean_absolute_error: 0.0824
# Epoch 15/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0116 - mean_absolute_error: 0.0850 - val_loss: 0.0104 - val_mean_absolute_error: 0.0810
# Epoch 16/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0112 - mean_absolute_error: 0.0837 - val_loss: 0.0102 - val_mean_absolute_error: 0.0804
# Epoch 17/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0109 - mean_absolute_error: 0.0824 - val_loss: 0.0100 - val_mean_absolute_error: 0.0795
# Epoch 18/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0106 - mean_absolute_error: 0.0813 - val_loss: 0.0097 - val_mean_absolute_error: 0.0788
# Epoch 19/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0103 - mean_absolute_error: 0.0802 - val_loss: 0.0095 - val_mean_absolute_error: 0.0778
# Epoch 20/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0100 - mean_absolute_error: 0.0789 - val_loss: 0.0093 - val_mean_absolute_error: 0.0770
# Epoch 21/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0098 - mean_absolute_error: 0.0778 - val_loss: 0.0091 - val_mean_absolute_error: 0.0762
# Epoch 22/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0095 - mean_absolute_error: 0.0767 - val_loss: 0.0089 - val_mean_absolute_error: 0.0750
# Epoch 23/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0093 - mean_absolute_error: 0.0757 - val_loss: 0.0087 - val_mean_absolute_error: 0.0747
# Epoch 24/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0090 - mean_absolute_error: 0.0747 - val_loss: 0.0085 - val_mean_absolute_error: 0.0737
# Epoch 25/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0088 - mean_absolute_error: 0.0737 - val_loss: 0.0084 - val_mean_absolute_error: 0.0729
# Epoch 26/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0086 - mean_absolute_error: 0.0727 - val_loss: 0.0081 - val_mean_absolute_error: 0.0717
# Epoch 27/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0084 - mean_absolute_error: 0.0718 - val_loss: 0.0080 - val_mean_absolute_error: 0.0712
# Epoch 28/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0082 - mean_absolute_error: 0.0709 - val_loss: 0.0078 - val_mean_absolute_error: 0.0698
# Epoch 29/50
# 10/10 [==============================] - 0s 40ms/step - loss: 0.0080 - mean_absolute_error: 0.0701 - val_loss: 0.0076 - val_mean_absolute_error: 0.0693
# Epoch 30/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0078 - mean_absolute_error: 0.0692 - val_loss: 0.0075 - val_mean_absolute_error: 0.0687
# Epoch 31/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0076 - mean_absolute_error: 0.0683 - val_loss: 0.0073 - val_mean_absolute_error: 0.0673
# Epoch 32/50
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0074 - mean_absolute_error: 0.0675 - val_loss: 0.0071 - val_mean_absolute_error: 0.0666
# Epoch 33/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0072 - mean_absolute_error: 0.0668 - val_loss: 0.0071 - val_mean_absolute_error: 0.0664
# Epoch 34/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0070 - mean_absolute_error: 0.0659 - val_loss: 0.0068 - val_mean_absolute_error: 0.0650
# Epoch 35/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0068 - mean_absolute_error: 0.0651 - val_loss: 0.0067 - val_mean_absolute_error: 0.0642
# Epoch 36/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0067 - mean_absolute_error: 0.0644 - val_loss: 0.0066 - val_mean_absolute_error: 0.0640
# Epoch 37/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0065 - mean_absolute_error: 0.0636 - val_loss: 0.0064 - val_mean_absolute_error: 0.0625
# Epoch 38/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0064 - mean_absolute_error: 0.0629 - val_loss: 0.0062 - val_mean_absolute_error: 0.0618
# Epoch 39/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0062 - mean_absolute_error: 0.0620 - val_loss: 0.0061 - val_mean_absolute_error: 0.0613
# Epoch 40/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0060 - mean_absolute_error: 0.0611 - val_loss: 0.0060 - val_mean_absolute_error: 0.0605
# Epoch 41/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0059 - mean_absolute_error: 0.0605 - val_loss: 0.0058 - val_mean_absolute_error: 0.0597
# Epoch 42/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0058 - mean_absolute_error: 0.0599 - val_loss: 0.0056 - val_mean_absolute_error: 0.0585
# Epoch 43/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0056 - mean_absolute_error: 0.0591 - val_loss: 0.0056 - val_mean_absolute_error: 0.0581
# Epoch 44/50
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0055 - mean_absolute_error: 0.0582 - val_loss: 0.0054 - val_mean_absolute_error: 0.0574
# Epoch 45/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0054 - mean_absolute_error: 0.0578 - val_loss: 0.0052 - val_mean_absolute_error: 0.0561
# Epoch 46/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0052 - mean_absolute_error: 0.0569 - val_loss: 0.0052 - val_mean_absolute_error: 0.0558
# Epoch 47/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0051 - mean_absolute_error: 0.0561 - val_loss: 0.0051 - val_mean_absolute_error: 0.0557
# Epoch 48/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0049 - mean_absolute_error: 0.0551 - val_loss: 0.0049 - val_mean_absolute_error: 0.0540
# Epoch 49/50
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0048 - mean_absolute_error: 0.0546 - val_loss: 0.0047 - val_mean_absolute_error: 0.0534
# Epoch 50/50
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0047 - mean_absolute_error: 0.0539 - val_loss: 0.0046 - val_mean_absolute_error: 0.0527

# %%
tr_acc = history.history['mean_absolute_error']
tr_loss = history.history['loss']
val_acc = history.history['val_mean_absolute_error']
val_loss = history.history['val_loss']
index_loss = np.argmin(val_loss)
val_lowest = val_loss[index_loss]
index_acc = np.argmin(val_acc)
acc_highest = val_acc[index_acc]
Epochs = [i+1 for i in range(len(tr_acc))]
loss_label = f'best epoch= {str(index_loss + 1)}'
acc_label = f'best epoch= {str(index_acc + 1)}'

plt.figure(figsize= (20, 8))
plt.style.use('fivethirtyeight')

plt.subplot(1, 2, 1)
plt.plot(Epochs, tr_loss, 'r', label= 'Training loss')
plt.plot(Epochs, val_loss, 'g', label= 'Validation loss')
plt.scatter(index_loss + 1, val_lowest, s= 150, c= 'blue', label= loss_label)
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(Epochs, tr_acc, 'r', label= 'Training Accuracy')
plt.plot(Epochs, val_acc, 'g', label= 'Validation Accuracy')
plt.scatter(index_acc + 1 , acc_highest, s= 150, c= 'blue', label= acc_label)
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout
plt.show()

# %%
ann_y_pred = ann.predict(X_test)
# Out:
# 4/4 [==============================] - 0s 3ms/step

# %%
r2 = r2_score(y_test, y_pred)
print('R2 score:', r2)
# Out:
# R2 score: 0.9999999809931507

# %%
ann.evaluate(X_test, y_test)
# Out:
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0047 - mean_absolute_error: 0.0543
# [0.004690752364695072, 0.054291438311338425]

# %%
ann.predict([[40, 70000.500, 9550,534000]])
# Out:
# 1/1 [==============================] - 0s 38ms/step
# array([[167633.06]], dtype=float32)

# %%
plt.figure(figsize=(10, 6))
plt.scatter(y_test, y_pred, label='Linear Regression')
plt.scatter(y_test, ann_y_pred, label='ANN')
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], linestyle='--', color='gray')
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.title('Predicted vs. Actual Values')
plt.legend()
plt.show()
